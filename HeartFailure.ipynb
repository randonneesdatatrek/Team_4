# %%
# Let's import usefull pakages 
from sklearn import svm
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %%
# Let's us read and display our dataset
csvfile = pd.read_csv('C:/SLACK2/heart_failure_clinical_records_dataset.csv', sep =',')

# %%
csvfile.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %% [markdown]
# DATA EXPLORATION

# %%
# let's see the shape of heart failure dataset
print('the shape of heart failure dataset is :')
print(csvfile.shape)
print()

#let's see the size of our heart failure dataset 
print('the size of heart failure dataset is :')
print(csvfile.size)
print()
# Out:
# the shape of heart failure dataset is :
# (299, 13)
#
# the size of heart failure dataset is :
# 3887

# %%
# let's see if we have missed data in dataset
csvfile.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
# Let's see if dataset has null values 
csvfile.isnull().sum().any()
# Out:
# False

# %%
csvfile['DEATH_EVENT'].value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64
